# %% [markdown]
# # Python Packages
#
# We usually organize our files in different folders and subfolders based on some criteria, so that they can be managed easily and efficiently. For example, we keep all our games in a Games folder and we can even subcategorize according to the genre of the game or something like this. The same analogy is followed by the packages in Python.
#
# # What is a Python Package?
# Python modules may contain several classes, functions, variables, etc. whereas Python packages contain several modules. In simpler terms, Package in Python is a folder that contains various modules as files.
#
# ![Screenshot%202023-11-18%20132453.png](attachment:Screenshot%202023-11-18%20132453.png)
#
# ## Creating Package
# Let’s create a package in Python named gamepkg that will contain three subpackages sglevel, sgimage and sgsound. To create this subpackages follow the below steps:
#
# Create a folder named gamepkg.
# Inside this folder create an empty Python file i.e. __init__.py
# Then create three subpackages named sglevel, sgimage, and sgsound in this folder.

# %% [markdown]
# ![Screenshot%202023-11-18%20185955.png](attachment:Screenshot%202023-11-18%20185955.png)

# %% [markdown]
# ### Then Create 3 modules in each sub package as shown below

# %% [markdown]
# ![Screenshot%202023-11-18%20190025.png](attachment:Screenshot%202023-11-18%20190025.png)

# %% [markdown]
# # Understanding __init__.py
# __init__.py helps the Python interpreter recognize the folder as a package. It also specifies the resources to be imported from the modules. If the __init__.py is empty this means that all the functions of the modules will be imported. We can also specify the functions from each module to be made available.
#
# For example, we can also create the __init__.py file for the above module as:
#
# __init__.py
#
# This __init__.py will only allow the gamepkg and all the three modules to be imported.

# %% [markdown]
# ### Creating a module with five functions and checking if the file is running as module or script
#
# Import Modules from a Package
# We can import these Python modules using the from…import statement and the dot(.) operator.
#
# Syntax:
# import package_name.module_name

# %% [markdown]
# ![Screenshot%202023-11-18%20184845.png](attachment:Screenshot%202023-11-18%20184845.png)

# %% [markdown]
# ## Adding package to sys path

# %% [markdown]
# ![Screenshot%202023-11-18%20185955.png](attachment:Screenshot%202023-11-18%20185955.png)

# %% [markdown]
# ### import files in testing file as shown below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Testing mechanism to check for errors in the written functions

# %% [markdown]
# ![Screenshot%202023-11-18%20184211.png](attachment:Screenshot%202023-11-18%20184211.png)
